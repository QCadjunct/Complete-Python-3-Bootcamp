# %%
target_connection = {
    "MSSQL": {
        "DRIVER": "{ODBC Driver 17 for SQL Server}",
        "SERVER": "localhost",
        "PORT_NUMBER": 13001,
        "DATABASE_NAME": "CustomerTrigger",
        "USERNAME": "sa",
        "PASSWORD": "PH@123456789",
        "DEFAULT":"Custom Connection string",
    },
    "MYSQL": {
        "DRIVER": "{ODBC Driver 17 for SQL Server}",
        "SERVER": "localhost",
        "PORT_NUMBER": 13001,
        "DATABASE_NAME": "CustomerTrigger",
        "USERNAME": "sa",
        "PASSWORD": "PH@123456789",
        "DEFAULT":"Custom Connection string"},
    "POSTGRESQL": {
        "DRIVER": "{ODBC Driver 17 for SQL Server}",
        "SERVER": "localhost",
        "PORT_NUMBER": 13001,
        "DATABASE_NAME": "CustomerTrigger",
        "USERNAME": "sa",
        "PASSWORD": "PH@123456789",
        "DEFAULT":"Custom Connection string"},
}

# %%
f"DRIVER={target_connection['MSSQL']['DRIVER']};DATABASE_NAME={target_connection['MSSQL']['DATABASE_NAME']},PORT_NUMBER{target_connection['MSSQL']["PORT_NUMBER"]}"
# Out:
# 'DRIVER={ODBC Driver 17 for SQL Server};DATABASE_NAME=CustomerTrigger,PORT_NUMBER13001'

# %%
target_connection["MSSQL"]["USERNAME"]
# Out:
# 'sa'

# %%
target_connection["MSSQL"]
# Out:
# {'DRIVER': '{ODBC Driver 17 for SQL Server}',
#  'SERVER': 'localhost',
#  'PORT_NUMBER': 13001,
#  'DATABASE_NAME': 'CustomerTrigger',
#  'USERNAME': 'sa',
#  'PASSWORD': 'PH@123456789'}

# %%
target_connection["MSSQL"]["DEFAULT"]
# Out:
# 'Custom Connection string'

# %%
target_connection.keys()
target_connection.values()
# Out:
# dict_values([{'DRIVER': '{ODBC Driver 17 for SQL Server}', 'SERVER': 'localhost', 'PORT_NUMBER': 13001, 'DATABASE_NAME': 'CustomerTrigger', 'USERNAME': 'sa', 'PASSWORD': 'PH@123456789'}, {'DRIVER': '{ODBC Driver 17 for SQL Server}', 'SERVER': 'localhost', 'PORT_NUMBER': 13001, 'DATABASE_NAME': 'CustomerTrigger', 'USERNAME': 'sa', 'PASSWORD': 'PH@123456789'}, {'DRIVER': '{ODBC Driver 17 for SQL Server}', 'SERVER': 'localhost', 'PORT_NUMBER': 13001, 'DATABASE_NAME': 'CustomerTrigger', 'USERNAME': 'sa', 'PASSWORD': 'PH@123456789'}])
